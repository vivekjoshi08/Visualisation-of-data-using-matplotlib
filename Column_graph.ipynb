# %% [markdown]
# # Column Graph

# %% [markdown]
# #### Matplotlib
#
# **Matplotlib** is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# To know more about matplotlib library, refer to the link [here](https://matplotlib.org/)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# #### panda Basics
#
# We will now import the **pandas** module.

# %%
import pandas as pd

# %% [markdown]
# - Before plotting, we convert the column headings from a string to integer data type, since they represent numerical values.
# - Extract year from last 4 characters of each column name.
# - The current column names are structured as 'gdpPercap_(year)',
# - so we want to keep the (year) part only for clarity when plotting GDP vs. years
# - To do this we use strip(), which removes from the string the characters stated in the argument
# - This method works on strings, so we call str before strip()

# %%
df_europe = pd.read_csv(r'C:\Users\HP\Desktop\MachineLearning\Visualisation_of_data\Dataset\europe.csv', index_col = 'country')
df_europe.drop('Total', axis = 1, inplace = True)
df_europe.head(5)
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %%
yrs = df_europe.columns.str.strip('gdpPercap_')
df_europe.columns = yrs.astype(int)
df_europe.head(5)
# Out:
#                                1952         1957          1962          1967  \
# country
# Albania                 1601.056136  1942.284244   2312.888958   2760.196931
# Austria                 6137.076492  8842.598030  10750.721110  12834.602400
# Belgium                 8343.105127  9714.960623  10991.206760  13149.041190
# Bosnia and Herzegovina   973.533195  1353.989176   1709.683679   2172.352423
# Bulgaria                2444.286648  3008.670727   4254.337839   5577.002800
#
#                                 1972          1977          1982  \
# country
# Albania                  3313.422188   3533.003910   3630.880722
# Austria                 16661.625600  19749.422300  21597.083620
# Belgium                 16672.143560  19117.974480  20979.845890
# Bosnia and Herzegovina   2860.169750   3528.481305   4126.613157
# Bulgaria                 6597.494398   7612.240438   8224.191647
#
#                                 1987          1992          1997  \
# country
# ...

# %%
df_europe.plot(kind = 'bar', figsize = (18,10))
plt.ylabel('GDP per Capita')
plt.legend(loc = 0)

# %%
df_europe.loc['Belgium'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_europe.iloc[:2].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='country'>

# %%
df_europe.iloc[0:2, 0:].plot(kind='bar' )
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# #### Change position of Legend
#
# We may change the position of the legend on our graph by explicitly specifying the desired position.
# By defaut the position is 'upper right'
# Some other positions that can be defined for a legend are:
#
# <img src ="https://raw.githubusercontent.com/arpgpt/data-visualization/master/legend.jpg" align="left">

# %%
df_europe.loc['Belgium'].plot(kind = 'bar', figsize=(10,10))
plt.legend('best')

# %%
df_europe.loc['Belgium'].plot(kind='barh', color='cyan', figsize=(9,9), edgecolor='black')
plt.title('GDP of Belgium')
# Out:
# Text(0.5, 1.0, 'GDP of Belgium')

# %%
df_europe.loc['Belgium'].plot(kind='bar', figsize=(7,7), color='cyan', edgecolor= 'black')
plt.show()

# %%
df_europe.loc['Belgium'].plot(kind='bar', edgecolor='brown', color='yellow')
plt.show()

# %%
df_europe.loc["Belgium"].plot(kind='bar', color='red', edgecolor='black', figsize=(6,6))
plt.title('GDP of Belgium', color = 'white', size = 30)
plt.xlabel('GDP per capital', color = 'white', size = 20)
plt.ylabel('Years', color = 'white', size = 20)
plt.xticks(color='white', rotation = 45)
plt.yticks(color= 'white')
# Out:
# (array([    0.,  5000., 10000., 15000., 20000., 25000., 30000., 35000.,
#         40000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df_europe.loc['Belgium'].plot(kind='bar', hatch ='*', figsize=(7,7), color='red', edgecolor='black')
plt.title('Gdp of Belgium', color= 'white', size = 25)
plt.xlabel('years', color='white', size=20)
plt.ylabel('GDP per capital', color='white', size=20)
plt.show()

# %%
df_belgium = df_europe.loc['Belgium']
df_belgium
# Out:
# 1952     8343.105127
# 1957     9714.960623
# 1962    10991.206760
# 1967    13149.041190
# 1972    16672.143560
# 1977    19117.974480
# 1982    20979.845890
# 1987    22525.563080
# 1992    25575.570690
# 1997    27561.196630
# 2002    30485.883750
# 2007    33692.605080
# Name: Belgium, dtype: float64

# %% [markdown]
# We will plot the a column graph/ column chart using style sheets available. Use ***style.use()***

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot')

df = df_belgium.plot(kind='bar', figsize=(18,10), color ='red', width = 0.6)

plt.title('GDP per capita for belgium')

x_offset = 0
y_offset = 0

for p in df.patches:
    b = p.get_bbox()
    val = '{:.2f}'.format(b.y1 + b.y0)
    df.annotate(val, ((b.x0+b.x1)/2 +x_offset, b.y1 + y_offset))
    
plt.show()
