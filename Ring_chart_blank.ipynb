# %% [markdown]
# # Ring Plot

# %% [markdown]
# <div style="margin-top: 20px">
#
# <font size = 3>
#
# We will learn about a visualization tool namely **Ring Plot**, and learn how to create it using Matplotlib.
#
# A Ring Plot, also known as the Donut chart is essentially a Pie Chart with an area of the center cut out.
#
# To plot a ring chart we use the `plt.pie()` function.
# We may either add a circle at the center or play with the radius and width arguments to get a ring plot.
#
#
#
# </font>
# </div>

# %% [markdown]
# ## Exploring Datasets with pandas

# %% [markdown]
# pandas is an essential data analysis toolkit for Python. From their [website](https://pandas.pydata.org/):
#
# > pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python.
#
# The lab relies on pandas for data wrangling, analysis, and visualization. We encourage you to spend some time and familizare yourself with the pandas API Reference: [http://pandas.pydata.org/pandas-docs/stable/api.html.](http://pandas.pydata.org/pandas-docs/stable/api.html)

# %% [markdown]
# #### Matplotlib
#
# **Matplotlib** is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# To know more about matplotlib library, refer to the link [here](https://matplotlib.org/)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = [10,20,50,19,25]

plt.pie(data)

circle= plt.Circle( (0,0), 0.7, color = 'black')

p = plt.gcf()
p.gca().add_artist(circle) 
# The add_artist() is used to add an Artist to the axes, and return the artist.
# The artist is the object that knows how to take the Renderer and use it to put ink on the canvas. 
# Everything you see on a Matplotlib figure is an artist instance. 

plt.show()

# %% [markdown]
# This is what a basic ring plot looks like.
#
# The  trick is to make a pie chart and then add a white circle in the middle of the pie chart created.
# Another option is to use the `radius` and `width` arguments.

# %%
names = ['lab1', 'lab2', 'lab3', 'lab4']
data = [20,60,50,100]

plt.pie(data, labels = names)

circle = plt.Circle((0,0), 0.69, color = 'white')

p = plt.gcf()


p.gca().add_artist(circle)

plt.show()

# %% [markdown]
# ### Custom Color

# %%
names = ['lab1', 'lab2', 'lab3', 'lab4']
data = [20,60,50,100]
color_list = ['red', 'blue', 'orange', 'green']

plt.pie(data, labels = names, colors = color_list)

circle = plt.Circle((0,0), 0.69, color = 'white')

p = plt.gcf()


p.gca().add_artist(circle)

plt.show()

# %% [markdown]
# ### Custom Wedges

# %%
data = [10,50,30,80]
names = ['lab1', 'lab2', 'lab3', 'lab4']
plt.pie(data, wedgeprops = {'linewidth':5, 'edgecolor':'white'}, labels = names)

circle = plt.Circle( (0,0), 0.699, color ='white')
p = plt.gcf()
p.gca().add_artist(circle)

plt.show()

# %% [markdown]
# #### panda Basics
#
# We will now import the **pandas** module.

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\MachineLearning\Visualisation_of_data\Dataset\europe.csv')

df.head(5)
# Out:
#                   country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0                 Albania     1601.056136     1942.284244     2312.888958
# 1                 Austria     6137.076492     8842.598030    10750.721110
# 2                 Belgium     8343.105127     9714.960623    10991.206760
# 3  Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# 4                Bulgaria     2444.286648     3008.670727     4254.337839
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     2760.196931     3313.422188     3533.003910     3630.880722
# 1    12834.602400    16661.625600    19749.422300    21597.083620
# 2    13149.041190    16672.143560    19117.974480    20979.845890
# 3     2172.352423     2860.169750     3528.481305     4126.613157
# 4     5577.002800     6597.494398     7612.240438     8224.191647
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# ...

# %% [markdown]
# We will use *pandas* `groupby` method to summarize the data by `Country`. The general process of `groupby` involves the following steps:
#
# 1. **Split:** Splitting the data into groups based on some criteria.
# 2. **Apply:** Applying a function to each group independently:
#        .sum()
#        .count()
#        .mean()
#        .std()
#        .aggregate()
#        .apply()
#        .etc..
# 3. **Combine:** Combining the results into a data structure.
#
# <img src = https://ibm.box.com/shared/static/tkfhxqkehfzpclco8f0eazhie33uxj9j.png,   height=400, align = "center">

# %%
df1 = df.groupby('country', axis = 0).sum()
df1.head(5)
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %% [markdown]
# We will now pass in `kind = 'pie'` keyword, along with the following additional parameters:
# - `autopct` -  is a string or function used to label the wedges with their numeric value. The label will be placed inside the wedge. If it is a format string, the label will be `fmt%pct`.
# - `startangle` - rotates the start of the pie chart by angle degrees counterclockwise from the x-axis.
# - `shadow` - Draws a shadow beneath the pie (to give a 3D feel).

# %%
df1['Total'].plot(kind = 'pie',
                figsize = (12,12),
                autopct = '%1.1f%%',
                shadow = True,
                startangle = 0,
                wedgeprops = {'linewidth':4, 'edgecolor':'white'}
                )

plt.title('GDP of European Countries', color = 'white', size = '25')
plt.axis('equal')

p = plt.gcf()

circle = plt.Circle((0,0), 0.7, color = 'white')
                    
p.gca().add_artist(circle)
                    
plt.show()
